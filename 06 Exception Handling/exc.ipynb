# %% [markdown]
# # Exception Handling
# When you perform some incorrect operations you get an exception in python

# %%
a = 
print(a/0)
# Out:
#   Cell In[2], line 1
#     a =
#         ^
# SyntaxError: invalid syntax

# %%
b = "Example"
print(b / 12)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 b = "Example"
# ----> 2 print(b / 12)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
a = "28"
print(a, type(a))
# Out:
# 28 <class 'str'>

# %%
b = int(a)
print(b, type(b))
# Out:
# 28 <class 'int'>

# %%
c = "abc"
d = int(c)
print(3 + 5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 2
#       1 c = "abc"
# ----> 2 d = int(c)
#       3 print(3 + 5)
#
# ValueError: invalid literal for int() with base 10: 'abc'

# %% [markdown]
# # Division function without exception handling

# %%
def division(a: int | float, b: int | float) -> float:
    c = a / b
    return c

# %%
d1 = division(a=23, b=7)
print(d1)
print("completed")
# Out:
# 3.2857142857142856
# completed

# %%
d2 = division(a=25, b=0)
print(d2)
print("Completed")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 d2 = division(a=25, b=0)
#       2 print(d2)
#       3 print("Completed")
#
# Cell In[7], line 2, in division(a, b)
#       1 def division(a: int | float, b: int | float) -> float:
# ----> 2     c = a / b
#       3     return c
#
# ZeroDivisionError: division by zero

# %%
d2 = division(a="abc", b=3)
print(d2)
print("Completed")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 d2 = division(a="abc", b=3)
#       2 print(d2)
#       3 print("Completed")
#
# Cell In[7], line 2, in division(a, b)
#       1 def division(a: int | float, b: int | float) -> float:
# ----> 2     c = a / b
#       3     return c
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %% [markdown]
# # Generic Exception handling

# %%
help(Exception)
# Out:
# Help on class Exception in module builtins:
#
# class Exception(BaseException)
#  |  Common base class for all non-exit exceptions.
#  |
#  |  Method resolution order:
#  |      Exception
#  |      BaseException
#  |      object
#  |
#  |  Built-in subclasses:
#  |      ArithmeticError
#  |      AssertionError
#  |      AttributeError
#  |      BufferError
#  |      ... and 16 other subclasses
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs)
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from BaseException:
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __reduce__(self, /)
#  |      Helper for pickle.
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  __setstate__(self, object, /)
#  |
#  |  __str__(self, /)
#  |      Return str(self).
#  |
#  |  add_note(self, object, /)
#  |      Exception.add_note(note) --
#  |      add a note to the exception
#  |
#  |  with_traceback(self, object, /)
#  |      Exception.with_traceback(tb) --
#  |      set self.__traceback__ to tb and return self.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from BaseException:
#  |
#  |  __cause__
#  |      exception cause
#  |
#  |  __context__
#  |      exception context
#  |
#  |  __dict__
#  |
#  |  __suppress_context__
#  |
#  |  __traceback__
#  |
#  |  args

# %%
def division2(num: int | float, den: int | float) -> float | None:
    try:
        div = num / den
        return div
    except Exception as e:
        print(f"Exception occured : {e}")

# %%
a = division2(num=100, den=26)
print(a)
print("Completed")
# Out:
# 3.8461538461538463
# Completed

# %%
b = division2(num=25, den=0)
print(b)
print("Completed")
# Out:
# Exception occured : division by zero
# None
# Completed

# %%
c = division2(num="abc", den=4)
print(c)
print("Completed")
# Out:
# Exception occured : unsupported operand type(s) for /: 'str' and 'int'
# None
# Completed

# %%
d = division2(num="a", den="b")
print(d)
print("Completed")
# Out:
# Exception occured : unsupported operand type(s) for /: 'str' and 'str'
# None
# Completed

# %% [markdown]
# # Use differnent exceptions for each errors
