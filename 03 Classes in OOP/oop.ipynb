# %% [markdown]
# # Object Orinted Programming
# 1) Class is similar to blue print
# 2) One class can have multiple objects

# %%
age = 23

# %%
print(type(age))
# Out:
# <class 'int'>

# %%
marks = 89

# %%
print(type(marks))
# Out:
# <class 'int'>

# %%
a = [2, 3, 4, 5, 6, 7, 8]

# %%
print(type(a))
# Out:
# <class 'list'>

# %%
b = (1, 2, 3, 4, 5, 6)

# %%
print(type(b))
# Out:
# <class 'tuple'>

# %%
c = {"a": 1, "b": 2, "c": 3, "d": 4}

# %%
print(type(c))
# Out:
# <class 'dict'>

# %% [markdown]
# # Dataframe class

# %%
s = {
    "Roll_no": [101, 102, 103, 104, 105],
    "Name": ["Rahul", "Raman", "Naman", "Adity", "Suman"],
    "Marks": [89, 86, 90, 98, 88],
}

# %%
print(type(s))
# Out:
# <class 'dict'>

# %%
import pandas as pd

# %%
df = pd.DataFrame(s)

# %%
df
# Out:
#    Roll_no   Name  Marks
# 0      101  Rahul     89
# 1      102  Raman     86
# 2      103  Naman     90
# 3      104  Adity     98
# 4      105  Suman     88

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# # Dataframe attribute
# 1. df.shape
# 2. df.columns
# 3. df.index
# 4. df.values
# 5. df.size
# 6. df.dtypes

# %%
df.shape
# Out:
# (5, 3)

# %%
df.columns
# Out:
# Index(['Roll_no', 'Name', 'Marks'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df.values
# Out:
# array([[101, 'Rahul', 89],
#        [102, 'Raman', 86],
#        [103, 'Naman', 90],
#        [104, 'Adity', 98],
#        [105, 'Suman', 88]], dtype=object)

# %%
df.size
# Out:
# 15

# %%
df.dtypes
# Out:
# Roll_no     int64
# Name       object
# Marks       int64
# dtype: object

# %% [markdown]
# # Functions or Methods of Class Dataframe
# 1. df.info()
# 2. df.sort_values()
# 3. df.group_by()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Roll_no  5 non-null      int64
#  1   Name     5 non-null      object
#  2   Marks    5 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 252.0+ bytes

# %%
df.mean(numeric_only=True)["Marks"]
# Out:
# np.float64(90.2)

# %%
df.sort_values(by="Marks", ascending=False)
# Out:
#    Roll_no   Name  Marks
# 3      104  Adity     98
# 2      103  Naman     90
# 0      101  Rahul     89
# 4      105  Suman     88
# 1      102  Raman     86

# %% [markdown]
# # User Defined class

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Person:

    # Use a constrator function \_ \_init \_ \_ to define attributes of a class
    def __init__(self, name: str, age: int, gender: str, occupation: str):
        self.name = name
        self.age = age
        self.gender = gender
        self.occupation = occupation

    # can create any oyher method
    def intro(self):
        print(f"Hi there my name is {self.name}")
        print(f"I am {self.age} years old")
        print(f"I am {self.gender}")
        print(f"I work as a {self.occupation}")

# %% [markdown]
# # __ main__ in python means current file

# %%
p1 = Person(name="Sarthak", age=25, gender="Male", occupation="Engneer")
print(p1)

# %%
print(type(p1))
# Out:
# <class '__main__.Person'>

# %%
p1.name
# Out:
# 'Sarthak'

# %%
p1.age
# Out:
# 25

# %%
p1.occupation
# Out:
# 'Engneer'

# %%
p1.intro()
# Out:
# Hi there my name is Sarthak
# I am 25 years old
# I am Male
# I work as a Engneer

# %%
p2 = Person(name="Adity", age=26, gender="Female", occupation="HR")

# %%
print(p2)

# %%
p2.intro()
# Out:
# Hi there my name is Adity
# I am 26 years old
# I am Female
# I work as a HR

# %%
p2.age
# Out:
# 26

# %%
p2.name
# Out:
# 'Adity'

# %%
p2.occupation
# Out:
# 'HR'

# %% [markdown]
# # You can change attributes for an object

# %%
p2.age
# Out:
# 26

# %%
p2.age = 28

# %%
p2.age
# Out:
# 28

# %%
p2.occupation
# Out:
# 'HR'

# %%
p2.occupation = "Data Scientist"

# %%
p2.occupation
# Out:
# 'Data Scientist'

# %%
p2.intro()
# Out:
# Hi there my name is Adity
# I am 28 years old
# I am Female
# I work as a Data Scientist

# %%
p2

# %% [markdown]
# # Dunder functions
#     __repr__ -> proprer representation for class
#     __str__ -> print representation for class
